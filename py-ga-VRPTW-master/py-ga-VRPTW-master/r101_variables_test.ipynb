# %%
# -*- coding: utf-8 -*-

'''sample_R101.py'''

import random
from gavrptw.core import run_gavrptw



random.seed(64)

instance_name = 'R101'

unit_cost = 8.0
init_cost = 60.0
wait_cost = 0.5
delay_cost = 1.5

ind_size = 25
pop_size = 80
cx_pb = 0.85
mut_pb = 0.01
n_gen = 100

export_csv = True

run_gavrptw(instance_name=instance_name, unit_cost=unit_cost, init_cost=init_cost, \
    wait_cost=wait_cost, delay_cost=delay_cost, ind_size=ind_size, pop_size=pop_size, \
    cx_pb=cx_pb, mut_pb=mut_pb, n_gen=n_gen, export_csv=export_csv)
# Out:
# File: c:\Users\henri\Downloads\py-ga-VRPTW-master\py-ga-VRPTW-master\data\json\R101.json exists.
# Start of evolution
#   Evaluated 80 individuals
# -- Generation 0 --
#   Evaluated 73 individuals
#   Min 9.763345499035684e-05
#   Max 0.00012637256751296555
#   Avg 0.00011025092708161362
#   Std 6.546907888573291e-06
# -- Generation 1 --
#   Evaluated 68 individuals
#   Min 0.00010108721705405057
#   Max 0.00012637256751296555
#   Avg 0.00011150920584364803
#   Std 6.729618002789988e-06
# -- Generation 2 --
#   Evaluated 76 individuals
#   Min 0.00010108721705405057
#   Max 0.00012637256751296555
#   Avg 0.00011247838480624498
#   Std 5.564957782953168e-06
# -- Generation 3 --
#   Evaluated 70 individuals
#   Min 0.00010108721705405057
#   Max 0.00013454256528171876
#   Avg 0.00011292313412455482
#   Std 6.307899996973984e-06
# -- Generation 4 --
#   Evaluated 74 individuals
#   Min 0.00010108721705405057
#   Max 0.00012637256751296555
#   Avg 0.00011257017608191774
#   Std 5.459432552434849e-06
# -- Generation 5 --
#   Evaluated 72 individuals
#   Min 0.00010108721705405057
#   Max 0.00012637256751296555
#   Avg 0.00011208891267705596
#   Std 5.560134612035376e-06
# -- Generation 6 --
#   Evaluated 68 individuals
#   Min 0.00010108721705405057
#   Max 0.00012637256751296555
#   Avg 0.00011141030597953876
#   Std 5.58263047470419e-06
# -- Generation 7 --
#   Evaluated 62 individuals
#   Min 0.00010108721705405057
#   Max 0.00012637256751296555
#   Avg 0.00011048221876913168
#   Std 4.905123707792183e-06
# -- Generation 8 --
#   Evaluated 64 individuals
#   Min 0.00010108721705405057
#   Max 0.00012637256751296555
#   Avg 0.00011053898049568188
#   Std 4.628335888400599e-06
# -- Generation 9 --
#   Evaluated 67 individuals
#   Min 0.00010108721705405057
#   Max 0.00012637256751296555
#   Avg 0.00011087838818770013
#   Std 4.572492407976074e-06
# -- Generation 10 --
#   Evaluated 66 individuals
#   Min 0.00010108721705405057
#   Max 0.00012637256751296555
#   Avg 0.00011069675116778502
#   Std 4.085222857771027e-06
# -- Generation 11 --
#   Evaluated 68 individuals
#   Min 9.766298057963241e-05
#   Max 0.00012637256751296555
#   Avg 0.0001105602780251292
#   Std 5.246550701479143e-06
# -- Generation 12 --
#   Evaluated 65 individuals
#   Min 9.766298057963241e-05
#   Max 0.00012637256751296555
#   Avg 0.0001091935639019299
#   Std 4.870803727120998e-06
# -- Generation 13 --
#   Evaluated 62 individuals
#   Min 0.00010108721705405057
#   Max 0.00012637256751296555
#   Avg 0.00010980944421594068
#   Std 4.67335364558759e-06
# -- Generation 14 --
#   Evaluated 72 individuals
#   Min 0.00010108721705405057
#   Max 0.00012637256751296555
#   Avg 0.0001098966048088067
#   Std 4.705676982422791e-06
# -- Generation 15 --
#   Evaluated 72 individuals
#   Min 0.00010108721705405057
#   Max 0.00012637256751296555
#   Avg 0.00011097761039982258
#   Std 5.1811498072258065e-06
# -- Generation 16 --
#   Evaluated 62 individuals
#   Min 0.00010108721705405057
#   Max 0.00012637256751296555
#   Avg 0.00011198923634251167
#   Std 5.757843002812066e-06
# -- Generation 17 --
#   Evaluated 72 individuals
#   Min 0.00010108721705405057
#   Max 0.00012637256751296555
#   Avg 0.00011356830777884174
#   Std 6.424807388705605e-06
# -- Generation 18 --
#   Evaluated 70 individuals
#   Min 0.00010108721705405057
#   Max 0.00012637256751296555
#   Avg 0.00011321775161855897
#   Std 5.7660698468312805e-06
# -- Generation 19 --
#   Evaluated 66 individuals
#   Min 0.00010108721705405057
#   Max 0.00012637256751296555
#   Avg 0.00011293869967772888
#   Std 5.740753180905244e-06
# -- Generation 20 --
#   Evaluated 59 individuals
#   Min 0.00010108721705405057
#   Max 0.00012637256751296555
#   Avg 0.00011284551107582305
#   Std 5.215451390669517e-06
# -- Generation 21 --
#   Evaluated 67 individuals
#   Min 0.00010517714084760733
#   Max 0.00012637256751296555
#   Avg 0.00011401933042101082
#   Std 6.05266406847209e-06
# -- Generation 22 --
#   Evaluated 69 individuals
#   Min 0.00010517714084760733
#   Max 0.00012637256751296555
#   Avg 0.00011330520934328778
#   Std 4.75947128893051e-06
# -- Generation 23 --
#   Evaluated 64 individuals
#   Min 0.00010517714084760733
#   Max 0.00012637256751296555
#   Avg 0.00011418080933439049
#   Std 5.145938933044533e-06
# -- Generation 24 --
#   Evaluated 74 individuals
#   Min 9.85789299478791e-05
#   Max 0.00012637256751296555
#   Avg 0.00011434735469877829
#   Std 5.153272064324239e-06
# -- Generation 25 --
#   Evaluated 58 individuals
#   Min 0.00010517714084760733
#   Max 0.00012637256751296555
#   Avg 0.00011522841293045525
#   Std 5.656302140575798e-06
# -- Generation 26 --
#   Evaluated 72 individuals
#   Min 0.00010517714084760733
#   Max 0.00012637256751296555
#   Avg 0.00011558867036742161
#   Std 5.509650171701378e-06
# -- Generation 27 --
#   Evaluated 56 individuals
#   Min 0.00010517714084760733
#   Max 0.00013666513979327925
#   Avg 0.00011543006570684934
#   Std 5.416197816116405e-06
# -- Generation 28 --
#   Evaluated 70 individuals
#   Min 0.00010517714084760733
#   Max 0.00013666513979327925
#   Avg 0.00011617420635386961
#   Std 5.695482862383478e-06
# -- Generation 29 --
#   Evaluated 74 individuals
#   Min 0.00010517714084760733
#   Max 0.00013666513979327925
#   Avg 0.0001169280994551834
#   Std 6.15971783135607e-06
# -- Generation 30 --
#   Evaluated 68 individuals
#   Min 0.00010517714084760733
#   Max 0.00013666513979327925
#   Avg 0.00011838263430874975
#   Std 7.410184900261412e-06
# -- Generation 31 --
#   Evaluated 60 individuals
#   Min 0.00010517714084760733
#   Max 0.00013666513979327925
#   Avg 0.00011820209294725031
#   Std 7.145470691734356e-06
# -- Generation 32 --
#   Evaluated 72 individuals
#   Min 0.00010517714084760733
#   Max 0.00013666513979327925
#   Avg 0.0001186362903686046
#   Std 8.006303988401787e-06
# -- Generation 33 --
#   Evaluated 64 individuals
#   Min 0.00010517714084760733
#   Max 0.00013666513979327925
#   Avg 0.00011928797820619696
#   Std 8.139248644786687e-06
# -- Generation 34 --
#   Evaluated 66 individuals
#   Min 0.00010517714084760733
#   Max 0.00013666513979327925
#   Avg 0.00012101651530127444
#   Std 8.848278061093108e-06
# -- Generation 35 --
#   Evaluated 70 individuals
#   Min 0.00010517714084760733
#   Max 0.00013666513979327925
#   Avg 0.00012137738905385567
#   Std 8.829256707573396e-06
# -- Generation 36 --
#   Evaluated 70 individuals
#   Min 0.00010517714084760733
#   Max 0.00013666513979327925
#   Avg 0.00012081764743889451
#   Std 8.946879900681592e-06
# -- Generation 37 --
#   Evaluated 66 individuals
#   Min 0.0001107352917667125
#   Max 0.00013666513979327925
#   Avg 0.00012095835305103531
#   Std 8.22590971786622e-06
# -- Generation 38 --
#   Evaluated 70 individuals
#   Min 0.0001107352917667125
#   Max 0.00013666513979327925
#   Avg 0.00012262372163083542
#   Std 8.840969252647032e-06
# -- Generation 39 --
#   Evaluated 70 individuals
#   Min 0.0001107352917667125
#   Max 0.00013666513979327925
#   Avg 0.00012295913657599266
#   Std 9.010485937961406e-06
# -- Generation 40 --
#   Evaluated 68 individuals
#   Min 0.0001107352917667125
#   Max 0.0001384964960246912
#   Avg 0.00012677150195190758
#   Std 9.238291079174695e-06
# -- Generation 41 --
#   Evaluated 58 individuals
#   Min 0.0001107352917667125
#   Max 0.0001384964960246912
#   Avg 0.00012866118861817636
#   Std 9.378708589876883e-06
# -- Generation 42 --
#   Evaluated 66 individuals
#   Min 0.00011454112926100033
#   Max 0.0001384964960246912
#   Avg 0.00013040041571393536
#   Std 8.438277754601445e-06
# -- Generation 43 --
#   Evaluated 72 individuals
#   Min 0.00010936243760347788
#   Max 0.0001384964960246912
#   Avg 0.00012993605923905776
#   Std 8.766034554892287e-06
# -- Generation 44 --
#   Evaluated 70 individuals
#   Min 0.00010936243760347788
#   Max 0.0001384964960246912
#   Avg 0.00012998869987976427
#   Std 8.821602448235796e-06
# -- Generation 45 --
#   Evaluated 73 individuals
#   Min 0.00010936243760347788
#   Max 0.0001384964960246912
#   Avg 0.00012922002192284845
#   Std 8.979062432610158e-06
# -- Generation 46 --
#   Evaluated 70 individuals
#   Min 0.00010936243760347788
#   Max 0.0001384964960246912
#   Avg 0.00012765394645909654
#   Std 9.464137910244654e-06
# -- Generation 47 --
#   Evaluated 63 individuals
#   Min 0.00011421073101023662
#   Max 0.0001384964960246912
#   Avg 0.00012752784539446214
#   Std 9.235627915499778e-06
# -- Generation 48 --
#   Evaluated 71 individuals
#   Min 0.00011421073101023662
#   Max 0.00013955846710267592
#   Avg 0.00012847795374344918
#   Std 8.83601644575003e-06
# -- Generation 49 --
#   Evaluated 69 individuals
#   Min 0.00011421073101023662
#   Max 0.00013955846710267592
#   Avg 0.00013117016146537105
#   Std 7.497308875512544e-06
# -- Generation 50 --
#   Evaluated 62 individuals
#   Min 0.00011421073101023662
#   Max 0.00013955846710267592
#   Avg 0.00013260140372939728
#   Std 7.155720968513941e-06
# -- Generation 51 --
#   Evaluated 63 individuals
#   Min 0.00010936243760347788
#   Max 0.0001384964960246912
#   Avg 0.0001323024472691171
#   Std 8.014070391598834e-06
# -- Generation 52 --
#   Evaluated 72 individuals
#   Min 0.00010936243760347788
#   Max 0.0001384964960246912
#   Avg 0.00013076981867416493
#   Std 9.326013154189127e-06
# -- Generation 53 --
#   Evaluated 66 individuals
#   Min 0.00011421073101023662
#   Max 0.0001384964960246912
#   Avg 0.00013371975374370997
#   Std 6.973174101925134e-06
# -- Generation 54 --
#   Evaluated 70 individuals
#   Min 0.00011421073101023662
#   Max 0.0001384964960246912
#   Avg 0.0001348154522518349
#   Std 5.36761333578019e-06
# -- Generation 55 --
#   Evaluated 58 individuals
#   Min 0.00011421073101023662
#   Max 0.00013666513979327925
#   Avg 0.00013451472823034725
#   Std 6.031110441636432e-06
# -- Generation 56 --
#   Evaluated 70 individuals
#   Min 0.00011454112926100033
#   Max 0.00013666513979327925
#   Avg 0.00013573448006395401
#   Std 4.1976772611415545e-06
# -- Generation 57 --
#   Evaluated 66 individuals
#   Min 0.00012637256751296555
#   Max 0.00013666513979327925
#   Avg 0.00013627916833276746
#   Std 1.9554194402013966e-06
# -- Generation 58 --
#   Evaluated 70 individuals
#   Min 0.0001224406491372008
#   Max 0.00013666513979327925
#   Avg 0.0001362300193530704
#   Std 2.2334497949243138e-06
# -- Generation 59 --
#   Evaluated 62 individuals
#   Min 0.0001224406491372008
#   Max 0.00013666513979327925
#   Avg 0.0001362300193530704
#   Std 2.2334497949243138e-06
# -- Generation 60 --
#   Evaluated 74 individuals
#   Min 0.00012097890077794082
#   Max 0.00013666513979327925
#   Avg 0.00013628828962887143
#   Std 2.325035299878785e-06
# -- Generation 61 --
#   Evaluated 58 individuals
#   Min 0.00013152420064557578
#   Max 0.00013666513979327925
#   Avg 0.0001365801062239908
#   Std 5.799238776832667e-07
# -- Generation 62 --
#   Evaluated 70 individuals
#   Min 0.00013152420064557578
#   Max 0.00013666513979327925
#   Avg 0.00013643586911347093
#   Std 9.81243415804621e-07
# -- Generation 63 --
#   Evaluated 58 individuals
#   Min 0.0001339192547726399
#   Max 0.0001381427718246425
#   Avg 0.00013663357299908597
#   Std 3.628697292977761e-07
# -- Generation 64 --
#   Evaluated 72 individuals
#   Min 0.00013626048394409468
#   Max 0.0001381427718246425
#   Avg 0.00013667855199555646
#   Std 1.707612295615648e-07
# -- Generation 65 --
#   Evaluated 68 individuals
#   Min 0.00013626048394409468
#   Max 0.0001381427718246425
#   Avg 0.00013667855199555644
#   Std 1.707612295809411e-07
# -- Generation 66 --
#   Evaluated 66 individuals
#   Min 0.00013629668876409453
#   Max 0.0001381427718246425
#   Avg 0.00013667900455580643
#   Std 1.6969730587381577e-07
# -- Generation 67 --
#   Evaluated 64 individuals
#   Min 0.0001292837760478953
#   Max 0.0001381427718246425
#   Avg 0.000136609813547246
#   Std 8.559091956871802e-07
# -- Generation 68 --
#   Evaluated 70 individuals
#   Min 0.0001292837760478953
#   Max 0.00014272857883745817
#   Avg 0.0001364892514937989
#   Std 1.5095505166887595e-06
# -- Generation 69 --
#   Evaluated 64 individuals
#   Min 0.0001292837760478953
#   Max 0.0001381427718246425
#   Avg 0.00013651754650042869
#   Std 1.181064942730763e-06
# -- Generation 70 --
#   Evaluated 70 individuals
#   Min 0.0001292837760478953
#   Max 0.0001381427718246425
#   Avg 0.00013651198730281635
#   Std 1.2110857423705988e-06
# -- Generation 71 --
#   Evaluated 73 individuals
#   Min 0.0001292837760478953
#   Max 0.0001381427718246425
#   Avg 0.00013657876885650818
#   Std 9.474962714354986e-07
# -- Generation 72 --
#   Evaluated 75 individuals
#   Min 0.00013335479402129955
#   Max 0.0001410998364970679
#   Avg 0.00013664850590508267
#   Std 9.080862614267806e-07
# -- Generation 73 --
#   Evaluated 64 individuals
#   Min 0.00013335479402129955
#   Max 0.0001410998364970679
#   Avg 0.00013645249195400316
#   Std 1.2653887674380384e-06
# -- Generation 74 --
#   Evaluated 78 individuals
#   Min 0.00013199208109004008
#   Max 0.0001410998364970679
#   Avg 0.00013647332411476117
#   Std 1.1522359917890978e-06
# -- Generation 75 --
#   Evaluated 64 individuals
#   Min 0.00013106312452068863
#   Max 0.0001410998364970679
#   Avg 0.00013647585783495094
#   Std 1.4965817432853518e-06
# -- Generation 76 --
#   Evaluated 73 individuals
#   Min 0.00013106312452068863
#   Max 0.0001410998364970679
#   Avg 0.00013636044303464307
#   Std 1.725709219664523e-06
# -- Generation 77 --
#   Evaluated 62 individuals
#   Min 0.00013106312452068863
#   Max 0.0001410998364970679
#   Avg 0.0001362835257771641
#   Std 1.8154564594501315e-06
# -- Generation 78 --
#   Evaluated 66 individuals
#   Min 0.00013106312452068863
#   Max 0.0001410998364970679
#   Avg 0.0001363876547238723
#   Std 1.8950084214050435e-06
# -- Generation 79 --
#   Evaluated 74 individuals
#   Min 0.00013106312452068863
#   Max 0.0001410998364970679
#   Avg 0.00013618646368138246
#   Std 2.1125863298886152e-06
# -- Generation 80 --
#   Evaluated 72 individuals
#   Min 0.00013106312452068863
#   Max 0.0001410998364970679
#   Avg 0.00013642147027656537
#   Std 2.2380087845059778e-06
# -- Generation 81 --
#   Evaluated 76 individuals
#   Min 0.00013106312452068863
#   Max 0.0001410998364970679
#   Avg 0.00013603315552369004
#   Std 2.2929116911323568e-06
# -- Generation 82 --
#   Evaluated 72 individuals
#   Min 0.00012977229217533772
#   Max 0.0001410998364970679
#   Avg 0.00013558430634887217
#   Std 2.623542691145651e-06
# -- Generation 83 --
#   Evaluated 76 individuals
#   Min 0.00012977229217533772
#   Max 0.00014581247866046906
#   Avg 0.0001358863180933392
#   Std 2.9751270246935424e-06
# -- Generation 84 --
#   Evaluated 68 individuals
#   Min 0.00012977229217533772
#   Max 0.00013945688047910495
#   Avg 0.0001358133556796491
#   Std 2.7476363312125777e-06
# -- Generation 85 --
#   Evaluated 66 individuals
#   Min 0.00012668146134003848
#   Max 0.00013945688047910495
#   Avg 0.00013565804598305605
#   Std 2.928691348728628e-06
# -- Generation 86 --
#   Evaluated 68 individuals
#   Min 0.00012023737201005252
#   Max 0.00013945688047910495
#   Avg 0.00013543969962327351
#   Std 3.3505789018246147e-06
# -- Generation 87 --
#   Evaluated 60 individuals
#   Min 0.00012023737201005252
#   Max 0.00013945688047910495
#   Avg 0.00013500515942339595
#   Std 3.6776316133022366e-06
# -- Generation 88 --
#   Evaluated 66 individuals
#   Min 0.00012023737201005252
#   Max 0.00013945688047910495
#   Avg 0.00013518602825648285
#   Std 4.019656213828756e-06
# -- Generation 89 --
#   Evaluated 70 individuals
#   Min 0.00012023737201005252
#   Max 0.00013945688047910495
#   Avg 0.00013502587952568182
#   Std 3.995930105880276e-06
# -- Generation 90 --
#   Evaluated 64 individuals
#   Min 0.00012023737201005252
#   Max 0.00013945688047910495
#   Avg 0.00013500470996546726
#   Std 4.002847780559303e-06
# -- Generation 91 --
#   Evaluated 62 individuals
#   Min 0.00012218389659109566
#   Max 0.00013945688047910495
#   Avg 0.00013559284325819165
#   Std 3.520667212237405e-06
# -- Generation 92 --
#   Evaluated 66 individuals
#   Min 0.00013106312452068863
#   Max 0.00013945688047910495
#   Avg 0.00013564407271201363
#   Std 3.125290448158342e-06
# -- Generation 93 --
#   Evaluated 64 individuals
#   Min 0.00013106312452068863
#   Max 0.00013945688047910495
#   Avg 0.00013598593536344542
#   Std 3.0889511943201325e-06
# -- Generation 94 --
#   Evaluated 62 individuals
#   Min 0.00013106312452068863
#   Max 0.00013945688047910495
#   Avg 0.00013562884621777055
#   Std 3.297747153080641e-06
# -- Generation 95 --
#   Evaluated 60 individuals
#   Min 0.00013106312452068863
#   Max 0.00013945688047910495
#   Avg 0.00013584938665527302
#   Std 3.1730864402066626e-06
# -- Generation 96 --
#   Evaluated 72 individuals
#   Min 0.00011774918667899063
#   Max 0.00013945688047910495
#   Avg 0.00013603752667734847
#   Std 3.695842383805547e-06
# -- Generation 97 --
#   Evaluated 70 individuals
#   Min 0.00011774918667899063
#   Max 0.00013945688047910495
#   Avg 0.00013590196708407727
#   Std 3.77746360847566e-06
# -- Generation 98 --
#   Evaluated 66 individuals
#   Min 0.00011774918667899063
#   Max 0.00013945688047910495
#   Avg 0.00013565872850886872
#   Std 3.940167230155241e-06
# -- Generation 99 --
#   Evaluated 66 individuals
#   Min 0.00013106312452068863
#   Max 0.00013945688047910495
#   Avg 0.00013578228181517323
#   Std 3.5516698873530386e-06
# -- End of (successful) evolution --
# Best individual: [4, 21, 23, 22, 18, 19, 2, 16, 13, 12, 25, 9, 8, 14, 15, 6, 17, 5, 3, 20, 1, 24, 10, 11, 7]
# Fitness: 0.00013945688047910495
#   Vehicle 1's route: 0 - 4 - 21 - 23 - 22 - 18 - 19 - 0
#   Vehicle 2's route: 0 - 2 - 16 - 13 - 12 - 25 - 0
#   Vehicle 3's route: 0 - 9 - 8 - 14 - 15 - 6 - 0
#   Vehicle 4's route: 0 - 17 - 5 - 3 - 20 - 1 - 0
#   Vehicle 5's route: 0 - 24 - 10 - 11 - 7 - 0
# Total cost: 7170.675240723111
# Write to file: c:\Users\henri\Downloads\py-ga-VRPTW-master\py-ga-VRPTW-master\results\R101_uC8.0_iC60.0_wC0.5_dC1.5_iS25_pS80_cP0.85_mP0.01_nG100.csv
# File: c:\Users\henri\Downloads\py-ga-VRPTW-master\py-ga-VRPTW-master\results\R101_uC8.0_iC60.0_wC0.5_dC1.5_iS25_pS80_cP0.85_mP0.01_nG100.csv exists. Overwrite.
# [[4, 21, 23, 22, 18, 19], [2, 16, 13, 12, 25], [9, 8, 14, 15, 6], [17, 5, 3, 20, 1], [24, 10, 11, 7]]
# [[4, 21, 23, 22, 18, 19],
#  [2, 16, 13, 12, 25],
#  [9, 8, 14, 15, 6],
#  [17, 5, 3, 20, 1],
#  [24, 10, 11, 7]]

# %%
gavrptw.core.ind2route(individual=2, instance='R101')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 gavrptw.core.ind2route(individual=2, instance='R101')
#
# NameError: name 'gavrptw' is not defined
